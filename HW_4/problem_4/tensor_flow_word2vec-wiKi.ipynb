# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import string
import collections
import numpy as np
import random
import tensorflow as tf
import math
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import zipfile

from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builti

from tensorflow.contrib.tensorboard.plugins import projector

# %%
current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
FLAGS, unparsed = parser.parse_known_args()

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(FLAGS.log_dir):
  os.makedirs(FLAGS.log_dir)

# %%
fd = open("text8","r")
data = fd.read()
fd.close()

# %%
tNG_data = data

# %%
tNG_data = data.split(" ")

# %%
print(tNG_data[:5])
# Out:
# ['', 'anarchism', 'originated', 'as', 'a']

# %%
def remove_punctuation(s):
    tr = str.maketrans("", "", string.punctuation)
    ##s = "Hello! It is time to remove punctuations. It is easy, you will see."
    s = s.translate(tr)
    return s

# %%
#tNG_data

# %%
low = []
for line in tNG_data:
    #print(line)
    if line == '':# skip the empty line
        continue
    
    #line = line.replace('\n',' ') # replaces new lines to empty spaces
    #line = line.lstrip()
    #line = remove_punctuation(line)
    lines=line
    
    low.append(lines)

# %%
print(low[:10])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
vocabulary = low

# %%
vocabulary_size = 50000

#"""Process raw inputs into a dataset."""
def build_dataset(words, n_words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
len(count)
# Out:
# 50000

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
print(labels)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],reverse_dictionary[labels[i, 0]])
# Out:
# [[  12]
#  [5234]
#  [   6]
#  [3081]
#  [ 195]
#  [  12]
#  [   2]
#  [   6]]
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
#valid_examples = np.random.choice(valid_window, valid_size, replace=False)
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
        embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
        nce_weights = tf.Variable(
          tf.truncated_normal(
              [vocabulary_size, embedding_size],
              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From <ipython-input-17-286668628e63>:68: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(FLAGS.log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
    # Feed metadata variable to session for visualizing the graph in TensorBoard.
    _, summary, loss_val = session.run(
        [optimizer, merged, loss],
        feed_dict=feed_dict,
        run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(FLAGS.log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()
# Out:
# Initialized
# Average loss at step  0 :  288.29278564453125
# Nearest to six: usk, mediocrity, lgbt, decorate, biodiversity, pr, afrika, minimalism,
# Nearest to one: carriages, nationalistic, entrails, quranic, birthdays, schiavo, ambient, drawer,
# Nearest to other: liquidity, troublesome, robotics, misogyny, slashdot, esther, parsons, volatile,
# Nearest to at: oriente, indonesia, comedic, annex, kur, parking, mahdi, london,
# Nearest to these: curie, sensitive, hadad, quarrel, tamers, lovecraft, toru, macross,
# Nearest to up: electronically, wreck, abolitionists, peritoneum, pataki, russa, equilateral, finalised,
# Nearest to there: anodes, means, inordinate, tyrone, earner, bookmarks, crimp, spelled,
# Nearest to about: vestibule, shelved, relieves, gba, blossoms, airliners, ow, forfeit,
# Nearest to are: viktor, chronometer, persistent, argues, muds, lms, panyu, roleplaying,
# Nearest to so: licentious, wendish, defender, hemisphere, observers, improvement, geffen, stra,
# Nearest to on: triads, slashed, inconsistency, shandy, mentha, samarkand, laptop, domestic,
# Nearest to the: muggles, atari, tung, guam, junius, watergate, petrovi, strewn,
# Nearest to its: reciprocating, shillings, deoxygenated, romances, intracellular, skull, formant, peppermint,
# Nearest to would: headache, strictly, sio, specific, practising, fughetta, inexorably, compulsion,
# Nearest to as: williamson, kodansha, foobar, researchers, wronged, revolved, coyotes, demyelinating,
# Nearest to seven: sis, posits, pencil, incursion, hlich, rabi, spitz, annual,
# Average loss at step  2000 :  114.40273103713989
# Average loss at step  4000 :  52.5878305208683
# Average loss at step  6000 :  33.376916207313535
# Average loss at step  8000 :  22.93110117125511
# Average loss at step  10000 :  17.947421330571174
# Nearest to six: nine, zero, eight, one, agave, austin, bckgr, victoriae,
# Nearest to one: two, nine, zero, lymphoma, vocals, UNK, mosque, agave,
# Nearest to other: bckgr, through, jerusalem, f, aaron, UNK, meant, renouncing,
# Nearest to at: and, of, indonesia, word, spanish, elections, in, proclaimed,
# Nearest to these: sensitive, lovecraft, the, his, nothing, quarrel, systems, hoped,
# Nearest to up: manhattan, institution, allen, abolitionists, oxide, grow, yeast, var,
# Nearest to there: basins, vocals, dates, anodes, means, boards, lymphoma, fertilizer,
# Nearest to about: rsha, ibn, adjective, vocals, supposed, piper, tubing, nine,
# Nearest to are: is, viktor, liability, religious, were, sabotage, argues, finalist,
# Nearest to so: defender, agave, observers, sheet, improvement, hemisphere, voltage, economist,
# Nearest to on: in, for, and, of, coach, coke, generally, laptop,
# Nearest to the: a, and, one, UNK, its, webelements, lymphoma, of,
# Nearest to its: the, gall, oxide, dim, version, a, milne, incorrect,
# Nearest to would: headache, than, mosque, strictly, publishing, specific, occupations, pair,
# Nearest to as: coke, and, in, is, psi, tubing, by, archaeological,
# Nearest to seven: nine, bckgr, agave, zero, three, mathbf, four, lymphoma,
# Average loss at step  12000 :  13.924226600766183
# Average loss at step  14000 :  11.664100994586944
# Average loss at step  16000 :  10.187374959111214
# Average loss at step  18000 :  8.503658295869828
# Average loss at step  20000 :  8.107941858172417
# Nearest to six: nine, eight, zero, seven, four, five, circ, three,
# Nearest to one: two, agouti, six, three, nine, five, dasyprocta, operatorname,
# Nearest to other: bckgr, through, peptidoglycan, berwick, jerusalem, robotics, parsons, akm,
# Nearest to at: in, of, and, waite, coke, indonesia, circ, dasyprocta,
# Nearest to these: sensitive, lovecraft, his, the, hadad, arnaud, systems, antoninus,
# Nearest to up: asser, agouti, allen, manhattan, institution, stolen, abolitionists, oxide,
# Nearest to there: they, it, naur, vocals, dates, anodes, basins, fertilizer,
# Nearest to about: blossoms, vestibule, nine, operatorname, hbox, teflon, rsha, and,
# Nearest to are: were, is, was, religious, liability, gum, argues, viktor,
# Nearest to so: observers, defender, agave, sheet, wendish, therapies, painters, economist,
# Nearest to on: in, for, and, dasyprocta, of, two, from, coke,
# Nearest to the: a, its, this, his, one, dasyprocta, agouti, operatorname,
# Nearest to its: the, their, gall, his, a, nicaea, milne, brewery,
# Nearest to would: headache, could, occupations, pair, than, mosque, strictly, stationed,
# Nearest to as: agouti, by, coke, is, and, haliotis, in, tubing,
# Nearest to seven: nine, zero, eight, six, four, three, five, two,
# Average loss at step  22000 :  6.975598117113114
# Average loss at step  24000 :  6.785773765325546
# Average loss at step  26000 :  6.745536368131638
# Average loss at step  28000 :  6.343867600560189
# Average loss at step  30000 :  5.878935323476791
# Nearest to six: eight, four, nine, five, seven, zero, three, circ,
# Nearest to one: two, four, operatorname, three, eight, circ, agouti, six,
# Nearest to other: bckgr, peptidoglycan, through, troublesome, reuptake, robotics, akm, berwick,
# Nearest to at: in, and, amalthea, with, waite, circ, dasyprocta, coke,
# Nearest to these: lovecraft, systems, the, sensitive, his, arnaud, hadad, antoninus,
# Nearest to up: asser, agouti, interferon, allen, abolitionists, manhattan, institution, electronically,
# Nearest to there: it, they, which, naur, usually, he, dates, often,
# Nearest to about: vestibule, blossoms, teflon, operatorname, second, rsha, forfeit, hbox,
# Nearest to are: were, is, was, have, religious, zero, be, had,
# Nearest to so: observers, defender, sheet, clarence, therapies, painters, excepted, agave,
# Nearest to on: in, for, dasyprocta, from, abet, with, two, by,
# Nearest to the: its, his, their, a, this, agouti, dasyprocta, akihabara,
# Nearest to its: the, their, his, gall, a, amalthea, milne, agouti,
# Nearest to would: could, can, to, headache, may, occupations, inexorably, pair,
# Nearest to as: agouti, by, and, is, coke, operatorname, haliotis, in,
# Nearest to seven: eight, nine, four, five, six, zero, three, agouti,
# Average loss at step  32000 :  5.9684528434276585
# Average loss at step  34000 :  5.662602737545967
# Average loss at step  36000 :  5.792662429332733
# Average loss at step  38000 :  5.570699623823166
# Average loss at step  40000 :  5.294571068406105
# Nearest to six: eight, four, seven, five, three, nine, zero, circ,
# Nearest to one: two, four, six, eight, three, operatorname, five, zero,
# Nearest to other: zero, bckgr, peptidoglycan, volatile, troublesome, ia, akm, pentecost,
# Nearest to at: in, zero, waite, and, on, amalthea, with, between,
# Nearest to these: many, systems, lovecraft, sensitive, their, arnaud, zero, his,
# Nearest to up: electronically, asser, interferon, abolitionists, agouti, jason, allen, institution,
# Nearest to there: it, they, which, zero, he, usually, naur, often,
# Nearest to about: vestibule, blossoms, operatorname, second, supposed, zero, forfeit, raided,
# Nearest to are: were, is, have, zero, was, religious, while, be,
# Nearest to so: observers, defender, sheet, painters, clarence, zero, fragment, therapies,
# Nearest to on: in, for, from, abet, dasyprocta, at, zero, two,
# Nearest to the: its, his, zero, their, akihabara, a, agouti, one,
# Nearest to its: their, the, his, zero, gall, a, amalthea, nicaea,
# Nearest to would: could, can, may, headache, to, occupations, inexorably, stationed,
# Nearest to as: agouti, zero, operatorname, haliotis, became, by, coke, recitative,
# Nearest to seven: eight, six, five, four, nine, three, zero, agouti,
# Average loss at step  42000 :  5.337995021700859
# Average loss at step  44000 :  5.256649144053459
# Average loss at step  46000 :  5.253789346814155
# Average loss at step  48000 :  5.208971275448799
# Average loss at step  50000 :  5.007883560657501
# Nearest to six: four, eight, five, three, seven, nine, zero, circ,
# Nearest to one: two, four, three, six, seven, eight, five, operatorname,
# Nearest to other: bckgr, volatile, these, some, three, archelaus, ia, troublesome,
# Nearest to at: in, solicitation, on, from, three, with, coke, circ,
# Nearest to these: many, some, systems, lovecraft, their, the, three, sensitive,
# Nearest to up: electronically, abolitionists, asser, interferon, agouti, jason, kapoor, allen,
# Nearest to there: they, it, which, usually, he, franchisee, often, naur,
# Nearest to about: vestibule, blossoms, second, only, operatorname, forfeit, supposed, three,
# Nearest to are: were, is, have, was, be, johansen, while, religious,
# Nearest to so: observers, defender, painters, fragment, sheet, cis, clarence, excepted,
# Nearest to on: in, two, solicitation, four, for, from, dasyprocta, abet,
# Nearest to the: his, their, its, this, a, solicitation, operatorname, agouti,
# Nearest to its: their, the, his, generative, gall, brewery, nicaea, her,
# Nearest to would: could, can, may, will, to, must, kapoor, occupations,
# Nearest to as: agouti, operatorname, tabula, haliotis, coke, for, by, eight,
# Nearest to seven: eight, six, five, four, three, zero, nine, agouti,
# Average loss at step  52000 :  5.045095474243164
# Average loss at step  54000 :  5.17958940911293
# Average loss at step  56000 :  5.035154055953026
# Average loss at step  58000 :  5.051252666115761
# Average loss at step  60000 :  4.951785428643227
# Nearest to six: eight, four, five, seven, three, nine, zero, dasyprocta,
# Nearest to one: two, four, three, six, five, seven, eight, agouti,
# Nearest to other: these, some, many, three, bckgr, volatile, ia, troublesome,
# Nearest to at: in, solicitation, on, from, three, microsite, ursus, dasyprocta,
# Nearest to these: many, some, their, lovecraft, systems, three, other, there,
# Nearest to up: electronically, abolitionists, interferon, asser, agouti, kapoor, jason, statehood,
# Nearest to there: they, it, which, usually, he, this, franchisee, often,
# Nearest to about: vestibule, blossoms, only, operatorname, second, supposed, four, five,
# Nearest to are: were, is, have, be, johansen, while, kapoor, pulau,
# Nearest to so: nuclides, thibetanus, observers, painters, fragment, ursus, defender, clarence,
# Nearest to on: in, from, ursus, at, solicitation, upon, through, abet,
# Nearest to the: its, their, his, this, a, agouti, one, ursus,
# Nearest to its: their, the, his, her, generative, brewery, gall, milne,
# Nearest to would: could, can, may, will, must, to, should, might,
# Nearest to as: agouti, operatorname, thibetanus, tabula, haliotis, coke, in, by,
# Nearest to seven: eight, six, five, nine, four, zero, three, dasyprocta,
# Average loss at step  62000 :  5.01258056139946
# Average loss at step  64000 :  4.8264347624778745
# Average loss at step  66000 :  4.583939996123314
# Average loss at step  68000 :  4.96752121591568
# Average loss at step  70000 :  4.909368200302124
# Nearest to six: four, eight, five, seven, three, nine, two, zero,
# Nearest to one: six, two, four, five, three, seven, eight, dasyprocta,
# Nearest to other: some, many, these, various, two, aidan, ia, akm,
# Nearest to at: in, solicitation, on, three, violin, microsite, waite, ursus,
# Nearest to these: many, some, their, there, the, such, other, all,
# Nearest to up: electronically, interferon, abolitionists, asser, agouti, them, cebus, kapoor,
# Nearest to there: it, they, which, usually, this, he, often, franchisee,
# Nearest to about: only, blossoms, operatorname, vestibule, second, supposed, acc, kumar,
# Nearest to are: were, is, have, be, johansen, while, was, kapoor,
# Nearest to so: nuclides, thibetanus, observers, fragment, ursus, painters, brace, clarence,
# Nearest to on: in, upon, ursus, solicitation, through, abet, from, at,
# Nearest to the: their, its, his, this, a, ursus, agouti, operatorname,
# Nearest to its: their, his, the, her, cebus, generative, brewery, milne,
# Nearest to would: could, can, may, will, must, to, should, might,
# Nearest to as: agouti, operatorname, became, haliotis, by, recitative, dasyprocta, tabula,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Average loss at step  72000 :  4.760649241805076
# Average loss at step  74000 :  4.811680044412613
# Average loss at step  76000 :  4.726605737328529
# Average loss at step  78000 :  4.796777645647526
# Average loss at step  80000 :  4.803629208922386
# Nearest to six: four, seven, eight, five, three, nine, two, zero,
# Nearest to one: seven, six, two, three, five, agouti, operatorname, dasyprocta,
# Nearest to other: some, many, these, various, ecliptic, pentecost, akm, aidan,
# Nearest to at: in, solicitation, on, five, violin, iit, during, ursus,
# Nearest to these: many, some, such, their, all, there, other, slipknot,
# Nearest to up: electronically, out, interferon, abolitionists, asser, them, flies, ploughing,
# Nearest to there: it, they, which, usually, he, often, this, these,
# Nearest to about: only, blossoms, operatorname, vestibule, supposed, acc, kumar, second,
# Nearest to are: were, is, have, be, pulau, while, johansen, vec,
# Nearest to so: nuclides, observers, thibetanus, painters, brace, ursus, fragment, correlatives,
# Nearest to on: in, through, upon, ursus, solicitation, at, dasyprocta, abet,
# Nearest to the: their, its, a, agouti, ursus, akihabara, his, operatorname,
# Nearest to its: their, his, the, her, cebus, brewery, generative, nicaea,
# Nearest to would: could, can, may, will, must, to, might, should,
# Nearest to as: agouti, operatorname, became, iit, dasyprocta, haliotis, kapoor, by,
# Nearest to seven: six, eight, five, four, nine, three, one, zero,
# Average loss at step  82000 :  4.749855786085129
# Average loss at step  84000 :  4.754855112552643
# Average loss at step  86000 :  4.759897300481796
# Average loss at step  88000 :  4.742473336696625
# Average loss at step  90000 :  4.717552276849747
# Nearest to six: seven, eight, five, four, three, nine, zero, two,
# Nearest to one: two, four, seven, three, five, eight, six, operatorname,
# Nearest to other: some, these, many, various, ecliptic, two, pentecost, aidan,
# Nearest to at: in, solicitation, on, during, iit, three, five, ursus,
# Nearest to these: many, some, such, there, other, all, their, the,
# Nearest to up: out, electronically, them, interferon, abolitionists, asser, kittens, flies,
# Nearest to there: they, it, which, usually, he, often, these, this,
# Nearest to about: only, operatorname, blossoms, supposed, vestibule, acc, kumar, chymotrypsin,
# Nearest to are: were, is, have, be, while, pulau, joram, including,
# Nearest to so: nuclides, painters, thibetanus, observers, when, clarence, brace, ursus,
# Nearest to on: in, upon, through, ursus, at, solicitation, dasyprocta, from,
# Nearest to the: their, its, this, a, his, ursus, peacocks, operatorname,
# Nearest to its: their, his, the, her, cebus, generative, nicaea, akihabara,
# Nearest to would: could, can, may, will, must, might, should, to,
# Nearest to as: agouti, operatorname, became, by, peacocks, dasyprocta, iit, when,
# Nearest to seven: eight, six, five, four, nine, three, zero, one,
# Average loss at step  92000 :  4.664075037240982
# Average loss at step  94000 :  4.736700643539429
# Average loss at step  96000 :  4.685673849344253
# Average loss at step  98000 :  4.588723944067955
# Average loss at step  100000 :  4.694695119142533
# Nearest to six: seven, eight, five, four, three, nine, two, zero,
# Nearest to one: two, four, seven, six, three, five, eight, dasyprocta,
# Nearest to other: these, various, some, many, ecliptic, two, akm, pentecost,
# Nearest to at: in, solicitation, during, on, iit, under, three, ursus,
# Nearest to these: many, some, such, their, all, other, the, several,
# Nearest to up: out, electronically, them, interferon, abolitionists, flies, asser, him,
# Nearest to there: they, it, he, which, usually, often, this, franchisee,
# Nearest to about: only, operatorname, blossoms, supposed, vestibule, acc, that, until,
# Nearest to are: were, is, have, be, while, these, pulau, johansen,
# Nearest to so: nuclides, boutros, when, painters, brace, observers, thibetanus, fragment,
# Nearest to on: upon, in, through, ursus, at, dasyprocta, solicitation, callithrix,
# Nearest to the: their, a, its, this, his, operatorname, ursus, cebus,
# Nearest to its: their, his, the, her, cebus, generative, apatosaurus, heyerdahl,
# Nearest to would: could, can, may, will, must, might, should, to,
# Nearest to as: agouti, operatorname, became, peacocks, dasyprocta, iit, by, circ,
# Nearest to seven: eight, six, five, four, nine, three, zero, dasyprocta,

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(
        label,
        xy=(x, y),
        xytext=(5, 2),
        textcoords='offset points',
        ha='right',
        va='bottom')

  plt.savefig(filename)


try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(
      perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'wiki_tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)

# %%
gettempdir()
# Out:
# '/var/folders/d0/vtcq_yxd4_l06mjb3n9wmb0m0000gn/T'

# %%
print(reverse_dictionary[90])
# Out:
# In

# %%
from sklearn.metrics.pairwise import cosine_similarity
sim1 = cosine_similarity(final_embeddings)

# %%
valid_word = 'the'
key = 0
for k,v in reverse_dictionary.items():
    if v == valid_word:
        key = k
        break
i=key
top_k = 20  # number of nearest neighbors
print("i:",i)

nearest = (-sim1[i, :]).argsort()[1:top_k + 1]
log_str = 'Nearest to %s:' % valid_word
for k in xrange(top_k):
    close_word = reverse_dictionary[nearest[k]]
    log_str = '%s %s,' % (log_str, close_word)
print(log_str)
# Out:
# i: 1
# Nearest to the: their, a, its, this, his, operatorname, ursus, cebus, solicitation, peacocks, agouti, dasyprocta, microcebus, any, goto, akihabara, stenella, albury, abet, mitral,
